# %% [markdown]
# # Train Demand Forecast Model
#
# Run the cells below to train the demand forecast model and create forecast rows without using the CLI.

# %%
import os
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "manage.py").exists():
    PROJECT_ROOT = Path.cwd().parent

os.chdir(PROJECT_ROOT)
sys.path.insert(0, str(PROJECT_ROOT / "src"))
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "config.settings")
os.environ.setdefault("DJANGO_ALLOW_ASYNC_UNSAFE", "true")

import django

django.setup()
PROJECT_ROOT
# Out:
# WindowsPath('c:/Users/ISSAH/Desktop/Projects/DIT/fyp2026/fyp2026_backend')

# %%
HORIZON_WEEKS = 4
ESTIMATORS = 200
MIN_ROWS = 200

# %%
from apps.demand_forecasting.training import train_and_forecast

result = train_and_forecast(
    horizon_weeks=HORIZON_WEEKS,
    estimators=ESTIMATORS,
    min_rows=MIN_ROWS,
)

print(
    "Demand forecast run "
    f"{result.run.public_id} completed: "
    f"MAE={result.run.mae}, RMSE={result.run.rmse}, "
    f"model={result.model_path}"
)
# Out:
# Demand forecast run xBS19QPr3c completed: MAE=2778.6571, RMSE=4821.6778, model=C:\Users\ISSAH\Desktop\Projects\DIT\fyp2026\fyp2026_backend\ai-models\demand_forecast.joblib
