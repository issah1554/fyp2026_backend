# %% [markdown]
# # Train Price Forecast Model
#
# Run the cells below to train the price forecasting model without using the CLI.

# %%
import os
import sys
from pathlib import Path

PROJECT_ROOT = Path.cwd()
if not (PROJECT_ROOT / "manage.py").exists():
    PROJECT_ROOT = Path.cwd().parent

os.chdir(PROJECT_ROOT)
sys.path.insert(0, str(PROJECT_ROOT / "src"))
os.environ.setdefault("DJANGO_SETTINGS_MODULE", "config.settings")

import django
from django.core.management import call_command

django.setup()
PROJECT_ROOT

# %%
call_command(
    "train_price_forecast",
    output_dir=str(PROJECT_ROOT / "data" / "price_forecasting"),
    model_dir=str(PROJECT_ROOT / "ai-models"),
)
